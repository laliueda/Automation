# %% [markdown]
# [Negativo - intimação da fazenda](#intfaz)
#
# [Negativo - junta arquivo](#junta)
#
# [Negativo - Renajud](#renajud)
#
# [Entre 1 e 5%](#1a5%)
#
# [Bloqueio parcial](#bloqparcial)
#
# [Bloqueio integral](#bloqint)
#
# [Bloqueio integral + liberação do excesso](#bloqexcesso)
#
# [Transferência](#transferencia)
#
# [Nova minuta](#nova)

# %%
# !pip install opencv-python

# %%
# !pip install keyboard
# Out:
# Collecting keyboard
#   Downloading keyboard-0.13.5-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.1/58.1 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: keyboard
# Successfully installed keyboard-0.13.5

# %% [markdown]
# https://pyautogui.readthedocs.io/en/latest/quickstart.html

# %%
import pyautogui as py
import time
import keyboard as kb

# %%
py.PAUSE = 0.5

# %% [markdown]
# ## Consulta protocolo

# %%
with py.hold('ctrl'):
    py.press(['tab', 'tab', 'tab'])

# Copia número do processo
py.moveTo(1302, 995)
py.click()
py.press('pgup')
py.moveTo(252, 621)
py.click()
py.hotkey('ctrl', 'shift','tab')
py.hotkey('ctrl', 'shift','tab')

# Abre menu sisbajud
py.moveTo(62, 292)
py.click()
py.moveTo(177, 490)
py.click()
py.moveTo(963, 661)
py.click()
py.moveTo(361, 812)
py.click()
py.hotkey('ctrl', 'a')
py.press('backspace')
py.hotkey('ctrl', 'v')
py.press('enter')
py.moveTo(2684, 1588)
py.click()
py.moveTo(2525, 1465)
py.click()

# %% [markdown]
# <a id='intfaz'></a>
# ## Negativo - intimação da fazenda

# %%
# Salvar o arquivo PFD
py.hotkey('ctrl','tab')
exp = py.locateCenterOnScreen('exportar.png', confidence = 0.7)
py.click(exp.x, exp.y)
time.sleep(1.5)
py.moveTo(2775, 259)
py.click()
py.write('sisbajud')
py.press('enter')
py.press('left')
py.press('enter')
py.hotkey('ctrl','w')

# Voi para o Eproc e sobe a página para cima
py.keyDown('ctrl')
py.press('tab')
py.press('tab')
py.keyUp('ctrl')
py.moveTo(1347, 829)
py.click()
py.press('pgup')

# Abre as preferências no Eproc
py.press('pgdn')
pref = py.locateCenterOnScreen('preferencias.png', confidence = 0.7)
py.click(pref.x, pref.y)
juntInt = py.locateCenterOnScreen('Junt int.png', confidence = 0.7)
py.click(juntInt.x, juntInt.y)

# Remove localizador e clica fora
py.moveTo(684, 823)
py.click()
py.moveTo(1476, 1537)
py.click()
py.press('pgdn')

# Intimação da fazenda e clica fora
time.sleep(1)
py.moveTo(321, 1325)
py.click()
py.press('tab')
py.write('60')
py.moveTo(1448, 1576)
py.click()

# Juntar o arquivo
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('enter')
py.write('sisbajud.pdf')
py.press('enter')
py.press('tab')
py.press('tab')
py.write('sb')
time.sleep(1.5)
py.press('down')
py.press('enter')
py.press('tab')
py.write('negativo')
py.press('tab')
py.press('tab')
py.press('enter')

# %% [markdown]
# <a id="junta"></a>
# ### Negativo junta arquivo

# %%
# Salvar o arquivo PFD
py.hotkey('ctrl','tab')
exp = py.locateCenterOnScreen('exportar.png', confidence = 0.7)
py.click(exp.x, exp.y)
time.sleep(1.5)
py.moveTo(2775, 259)
py.click()
py.write('sisbajud')
py.press('enter')
py.press('left')
py.press('enter')
py.hotkey('ctrl','w')

# Abre as preferências no Eproc
py.keyDown('ctrl')
py.press('tab')
py.press('tab')
py.keyUp('ctrl')
py.moveTo(1316, 1439)
py.click()
py.press('pgup')
py.press('pgdn')
pref = py.locateCenterOnScreen('preferencias.png', confidence = 0.7)
py.click(pref.x, pref.y)
juntInt = py.locateCenterOnScreen('juntada.png', confidence = 0.6)
py.click(juntInt.x, juntInt.y)

# Clica fora
time.sleep(1)
py.moveTo(1316, 1439)
py.click()


# Juntar o arquivo
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('enter')
py.write('sisbajud.pdf')
py.press('enter')
py.press('tab')
py.press('tab')
py.write('sb')
time.sleep(1.5)
py.press('down')
py.press('enter')
py.press('tab')
py.write('Bloqueio negativo')
py.press('tab')
py.press('tab')
py.press('enter')
# Out:
# ---------------------------------------------------------------------------
# ImageNotFoundException                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     171         try:
# --> 172             return wrappedFunction(*args, **kwargs)
#     173         except pyscreeze.ImageNotFoundException:
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in locateCenterOnScreen(*args, **kwargs)
#     203     def locateCenterOnScreen(*args, **kwargs):
# --> 204         return pyscreeze.locateCenterOnScreen(*args, **kwargs)
#     205
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in locateCenterOnScreen(image, **kwargs)
#     446     """
# --> 447     coords = locateOnScreen(image, **kwargs)
#     448     if coords is None:
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in locateOnScreen(image, minSearchTime, **kwargs)
#     404             screenshotIm = screenshot(region=None)
# --> 405             retVal = locate(image, screenshotIm, **kwargs)
#     406             try:
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in locate(needleImage, haystackImage, **kwargs)
#     382     kwargs['limit'] = 1
# --> 383     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     384     if len(points) > 0:
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     256         if USE_IMAGE_NOT_FOUND_EXCEPTION:
# --> 257             raise ImageNotFoundException('Could not locate the image (highest confidence = %.3f)' % result.max())
#     258         else:
#
# ImageNotFoundException: Could not locate the image (highest confidence = 0.569)
#
# During handling of the above exception, another exception occurred:
#
# ImageNotFoundException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28556\3794914459.py in <module>
#       1 # Salvar o arquivo PFD
#       2 py.hotkey('ctrl','tab')
# ----> 3 exp = py.locateCenterOnScreen('exportar.png', confidence = 0.7)
#       4 py.click(exp.x, exp.y)
#       5 time.sleep(1.5)
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     172             return wrappedFunction(*args, **kwargs)
#     173         except pyscreeze.ImageNotFoundException:
# --> 174             raise ImageNotFoundException  # Raise PyAutoGUI's ImageNotFoundException.
#     175
#     176     return wrapper
#
# ImageNotFoundException:

# %%
# Intima da decisão
with py.hold('ctrl'):
    py.press(['tab', 'tab', 'tab'])
py.press('pgdn')
py.moveTo(1564, 1565)
py.click()
time.sleep(3)
pref2 = py.locateCenterOnScreen('pref intim.png', confidence = 0.7)
py.click(pref2.x, pref2.y)
intimexeq = py.locateCenterOnScreen('intim exeq.png', confidence = 0.7)
py.click(intimexeq.x, intimexeq.y)
py.moveTo(1125, 1257)
py.click()
time.sleep(1)
py.moveTo(1441, 1540)
py.click()
py.press('pgdn')
py.press('tab')
py.press('tab')
py.press('down')
py.moveTo(282, 1470)
py.click()
py.press('tab')
py.write('60')

# %% [markdown]
# <a id='renajud'></a>
# ### Negativo + renajud

# %%
# Salvar o arquivo PFD
py.hotkey('ctrl','tab')
exp = py.locateCenterOnScreen('exportar.png', confidence = 0.7)
py.click(exp.x, exp.y)
time.sleep(1.5)
py.moveTo(2775, 259)
py.click()
py.write('sisbajud')
py.press('enter')
py.press('left')
py.press('enter')
py.hotkey('ctrl','w')

# Abre as preferências no Eproc
py.keyDown('ctrl')
py.press('tab')
py.press('tab')
py.keyUp('ctrl')
py.press('pgdn')
pref = py.locateCenterOnScreen('preferencias.png', confidence = 0.7)
py.click(pref.x, pref.y)
juntInt = py.locateCenterOnScreen('juntada.png', confidence = 0.7)
py.click(juntInt.x, juntInt.y)

# Altera localizador
py.moveTo(1889, y=839)
py.click()
time.sleep(1.5)
py.write('renajud')
py.press('enter')

# Clica fora
py.moveTo(1442, 1506)
py.click()

# Juntar o arquivo
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('enter')
py.write('sisbajud.pdf')
py.press('enter')
py.press('tab')
py.press('tab')
py.write('sb')
time.sleep(1.5)
py.press('down')
py.press('enter')
py.press('tab')
py.write('Bloqueio negativo')
py.press('tab')
py.press('tab')
py.press('enter')

# %% [markdown]
# <a id='1a5%'></a>
# ## Entre 1 e 5% + conclusão

# %%
# Salvar o arquivo PFD
py.hotkey('ctrl','tab')
exp = py.locateCenterOnScreen('exportar.png', confidence = 0.7)
py.click(exp.x, exp.y)
time.sleep(1.5)
py.moveTo(2775, 259)
py.click()
py.write('sisbajud')
py.press('enter')
py.press('left')
py.press('enter')
py.hotkey('ctrl','w')

# Abre as preferências no Eproc
py.keyDown('ctrl')
py.press('tab')
py.press('tab')
py.keyUp('ctrl')
py.press('pgdn')
pref = py.locateCenterOnScreen('preferencias.png', confidence = 0.7)
py.click(pref.x, pref.y)
juntInt = py.locateCenterOnScreen('conclusao.png', confidence = 0.7)
py.click(juntInt.x, juntInt.y)

# Altera localizador e clica fora
time.sleep(1)
py.moveTo(1830, 831)
py.click()
time.sleep(1.3)
py.write('c/convenio')
py.press('enter')
py.moveTo(1409, 1467)
py.click()

# Juntar o arquivo
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('enter')
py.write('sisbajud.pdf')
py.press('enter')
py.press('tab')
py.press('tab')
py.write('sb')
time.sleep(1.5)
py.press('down')
py.press('enter')
py.press('tab')
py.write('Entre 1 e 5%')
py.press('tab')
py.press('tab')
py.press('enter')

# %% [markdown]
# <a id='bloqparcial'></a>
# ## Bloqueio parcial

# %%
# Salvar o arquivo PFD
py.hotkey('ctrl','tab')
exp = py.locateCenterOnScreen('exportar.png', confidence = 0.7)
py.click(exp.x, exp.y)
time.sleep(1.5)
py.moveTo(2775, 259)
py.click()
py.write('sisbajud')
py.press('enter')
py.press('left')
py.press('enter')
py.hotkey('ctrl','w')

# Abre as preferências no Eproc
py.keyDown('ctrl')
py.press('tab')
py.press('tab')
py.keyUp('ctrl')
py.press('pgdn')
pref = py.locateCenterOnScreen('preferencias.png', confidence = 0.7)
py.click(pref.x, pref.y)
juntInt = py.locateCenterOnScreen('juntada.png', confidence = 0.7)
py.click(juntInt.x, juntInt.y)

# Altera localizador e clica fora
time.sleep(1)
py.moveTo(1830, 831)
py.click()
time.sleep(1.3)
py.write('d/int')
py.press('enter')
py.moveTo(1487, 899)
py.click()
py.press('tab')
py.press('enter')
py.write('a/ ')
py.press('enter')
py.moveTo(1409, 1467)
py.click()

# Juntar o arquivo
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('enter')
py.write('sisbajud.pdf')
py.press('enter')
py.press('tab')
py.press('tab')
py.write('sb')
time.sleep(1.5)
py.press('down')
py.press('enter')
py.press('tab')
py.write('Bloqueio parcial')
py.press('tab')
py.press('tab')
py.press('enter')
# Out:
# ---------------------------------------------------------------------------
# ImageNotFoundException                    Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     171         try:
# --> 172             return wrappedFunction(*args, **kwargs)
#     173         except pyscreeze.ImageNotFoundException:
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in locateCenterOnScreen(*args, **kwargs)
#     203     def locateCenterOnScreen(*args, **kwargs):
# --> 204         return pyscreeze.locateCenterOnScreen(*args, **kwargs)
#     205
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in locateCenterOnScreen(image, **kwargs)
#     446     """
# --> 447     coords = locateOnScreen(image, **kwargs)
#     448     if coords is None:
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in locateOnScreen(image, minSearchTime, **kwargs)
#     404             screenshotIm = screenshot(region=None)
# --> 405             retVal = locate(image, screenshotIm, **kwargs)
#     406             try:
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in locate(needleImage, haystackImage, **kwargs)
#     382     kwargs['limit'] = 1
# --> 383     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     384     if len(points) > 0:
#
# ~\anaconda3\lib\site-packages\pyscreeze\__init__.py in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     256         if USE_IMAGE_NOT_FOUND_EXCEPTION:
# --> 257             raise ImageNotFoundException('Could not locate the image (highest confidence = %.3f)' % result.max())
#     258         else:
#
# ImageNotFoundException: Could not locate the image (highest confidence = 0.567)
#
# During handling of the above exception, another exception occurred:
#
# ImageNotFoundException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10744\1223447640.py in <module>
#       1 # Salvar o arquivo PFD
#       2 py.hotkey('ctrl','tab')
# ----> 3 exp = py.locateCenterOnScreen('exportar.png', confidence = 0.7)
#       4 py.click(exp.x, exp.y)
#       5 time.sleep(1.5)
#
# ~\anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     172             return wrappedFunction(*args, **kwargs)
#     173         except pyscreeze.ImageNotFoundException:
# --> 174             raise ImageNotFoundException  # Raise PyAutoGUI's ImageNotFoundException.
#     175
#     176     return wrapper
#
# ImageNotFoundException:

# %% [markdown]
# <a id='bloqint'></a>
# ## Bloqueio integral

# %%
# Salvar o arquivo PFD
py.hotkey('ctrl','tab')
exp = py.locateCenterOnScreen('exportar.png', confidence = 0.7)
py.click(exp.x, exp.y)
time.sleep(1.5)
py.moveTo(2775, 259)
py.click()
py.write('sisbajud')
py.press('enter')
py.press('left')
py.press('enter')
py.hotkey('ctrl','w')

# Abre as preferências no Eproc
py.keyDown('ctrl')
py.press('tab')
py.press('tab')
py.keyUp('ctrl')
py.press('pgdn')
pref = py.locateCenterOnScreen('preferencias.png', confidence = 0.7)
py.click(pref.x, pref.y)
juntInt = py.locateCenterOnScreen('juntada.png', confidence = 0.7)
py.click(juntInt.x, juntInt.y)

# Altera localizador
time.sleep(1)
py.moveTo(1857, 829)
py.click()
time.sleep(1.3)
py.write('d/int')
py.press('enter')
py.moveTo(1483, 907)
py.click()
py.press('tab')
py.press('enter')
time.sleep(1)
py.write('a/')
py.press('enter')

# Clica fora
py.moveTo(1409, 1467)
py.click()

# Juntar o arquivo
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('enter')
py.write('sisbajud.pdf')
py.press('enter')
py.press('tab')
py.press('tab')
py.write('sb')
time.sleep(1.5)
py.press('down')
py.press('enter')
py.press('tab')
py.write('Bloqueio integral')
py.press('tab')
py.press('tab')
py.press('enter')

# %% [markdown]
# <a id='bloqexcesso'></a>
# ## Bloqueio integral + liberação do excesso

# %%
# Salvar o arquivo PFD
py.hotkey('ctrl','tab')
exp = py.locateCenterOnScreen('recibo.png', confidence = 0.7)
py.click(exp.x, exp.y)
time.sleep(1.5)
py.moveTo(2775, 259)
py.click()
py.write('sisbajud')
py.press('enter')
py.press('left')
py.press('enter')
py.hotkey('ctrl','w')

# Abre as preferências no Eproc
py.keyDown('ctrl')
py.press('tab')
py.press('tab')
py.keyUp('ctrl')
py.press('pgdn')
pref = py.locateCenterOnScreen('preferencias.png', confidence = 0.7)
py.click(pref.x, pref.y)
juntInt = py.locateCenterOnScreen('juntada.png', confidence = 0.7)
py.click(juntInt.x, juntInt.y)

# Altera localizador
time.sleep(1)
py.moveTo(1857, 829)
py.click()
time.sleep(1.3)
py.write('d/int')
py.press('enter')
py.moveTo(1483, 907)
py.click()
py.press('tab')
py.press('enter')
py.write('a/ ')
py.press('enter')
py.moveTo(1409, 1467)
py.click()

# Remove todos os localizadores
py.moveTo(1111, 899)
py.click()

# Clica fora
py.moveTo(297, 1560)
py.click()

# Juntar o arquivo
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('enter')
py.write('sisbajud.pdf')
py.press('enter')
py.press('tab')
py.press('tab')
py.write('sb')
time.sleep(1.5)
py.press('down')
py.press('enter')
py.press('tab')
kb.write('Bloqueio integral + liberação do excesso')
py.press('tab')
py.press('tab')
py.press('enter')

# %% [markdown]
# <a id='transferencia'></a>
# ## Transferência

# %%
# Salvar o arquivo PFD
py.hotkey('ctrl','tab')
    
def click_if_found(image_path, confidence=0.7):
    try:
        center = py.locateCenterOnScreen(image_path, confidence=confidence)
        if center:
            py.click(center.x, center.y)
            return True  # Indicate success
    except py.ImageNotFoundException:
        print(f"Image '{image_path}' not found.")
    return False  # Indicate failure
if click_if_found('exportar.png'):
    print('Clicked exportar')
else:
    click_if_found('recibo.png')
    print('Clicked recibo')
time.sleep(1.5)
py.moveTo(2775, 259)
py.click()
py.write('sisbajud')
py.press('enter')
py.press('left')
py.press('enter')
py.hotkey('ctrl','w')

# Abre as preferências no Eproc
py.keyDown('ctrl')
py.press('tab')
py.press('tab')
py.keyUp('ctrl')
py.press('pgdn')
pref = py.locateCenterOnScreen('preferencias.png', confidence = 0.7)
py.click(pref.x, pref.y)
juntInt = py.locateCenterOnScreen('ato intim.png', confidence = 0.6)
py.click(juntInt.x, juntInt.y)

# Intimação da fazenda e clica fora
py.moveTo(1390, 1541)
py.click()
py.press('pgdn')
time.sleep(1)
py.moveTo(319, 1325)
py.click()
py.press('tab')
py.write('60')
py.moveTo(1429, 1537)
py.click()
py.press('pgdn')

# Juntar o ato ordinatório
py.moveTo(442, 865)
py.click()
time.sleep(0.8)
py.press('tab')
py.press('enter')
py.keyDown('shift')
py.press('tab')
py.press('tab')
py.press('tab')
py.keyUp('shift')
py.write('sisbajud transferir')
time.sleep(0.8)
py.press('down')
py.press('enter')
py.keyDown('shift')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.keyUp('shift')
py.press('enter')
time.sleep(9)

# Junta o arquivo PDF
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('tab')
py.press('enter')
py.write('sisbajud.pdf')
py.press('enter')
py.press('tab')
py.press('tab')
py.write('sb')
time.sleep(1.5)
py.press('down')
py.press('enter')
py.press('tab')
kb.write('Transferência')
py.press('tab')
py.press('tab')
py.press('enter')
# Out:
# Clicked exportar

# %% [markdown]
# <a id='nova'></a>
# ## Nova minuta

# %%
# Deixar "informações adicionais aberta"
# -*- coding: utf-8 -*-
with py.hold('ctrl'):
    py.press(['tab', 'tab', 'tab'])

# Copia número do processo
py.moveTo(1302, 995)
py.click()
py.press('pgup')
py.moveTo(252, 621)
py.click()
py.hotkey('ctrl', 'shift','tab')
py.hotkey('ctrl', 'shift','tab')

# Cria nova minuta
py.moveTo(62, 292)
py.click()
time.sleep(1)
py.moveTo(242, 402)
py.click()
py.moveTo(121, 494)
py.click()

# Preenche minuta
py.moveTo(321, 1436)
py.click()
py.write('berti')
py.press('down')
py.press('enter')
py.press('tab')
py.write('12695')
py.press('tab')
py.hotkey('ctrl', 'v')
py.press('tab')
py.write('exec')
py.press('tab')
py.write('00394460021653')
py.write('0216')
py.write('53')
time.sleep(1.2)
py.press('tab')
kb.write('UNIÃO - FAZENDA NACIONAL')
py.hotkey('tab')
py.hotkey('tab')
py.hotkey('tab')

# %%
# Protocolo
py.hotkey('ctrl', 'tab')
py.moveTo(136, 495)
py.click()
time.sleep(1)
py.click()
py.write("")
py.press('enter')
with py.hold('ctrl'):
    py.press(['tab', 'tab'])
py.moveTo(1372, 981)
py.click()
py.press('pgup')
py.moveTo(464, 789)
py.click()
py.press('backspace')
py.press('backspace')
py.write('sisbajud verif llt')
py.press('enter')
py.press('tab')
py.press('enter')
time.sleep(1)

# fecha abas
py.hotkey('ctrl','w')
py.hotkey('ctrl','w')
py.hotkey('ctrl', 'shift','tab')

# %%
py.position()
# Out:
# Point(x=2525, y=1465)
